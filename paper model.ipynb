# %%
import numpy as np
import pandas as pd
import os
from re import search
import shutil
import natsort
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2

# %%
DIR=r"C:\Users\Omar Atef\apple\Dataset\Images\Original Dataset"

# %%
train=pd.read_csv(r"C:\Users\Omar Atef\apple\Dataset\train.csv")
test=pd.read_csv(r"C:\Users\Omar Atef\apple\Dataset\test.csv")

# %%
train.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
image1=Image.open(r"C:\Users\Omar Atef\apple\Dataset\Images\Original Dataset\Test_0.jpg")
plt.imshow(image1)
plt.show()

# %%
class_names=train.loc[:,'healthy':].columns
print(class_names)
# Out:
# Index(['healthy', 'multiple_diseases', 'rust', 'scab'], dtype='object')

# %%
number=0
train['label']=0
for i in class_names:
    train['label']=train['label'] + train[i] * number
    number=number+1

# %%
def get_label_img(img):
    if search("Train",img):
        img=img.split('.')[0]
        label=train.loc[train['image_id']==img]['label']
        return label

# %%
# def create_train_data():
#     images=natsort.natsorted(os.listdir(DIR))
#     for img in tqdm(images):
#         label=get_label_img(img)
#         path=os.path.join(DIR,img)
        
#         if search("Train",img):
#             if (img.split("_")[1].split(".")[0]) and label.item()==0:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\healthy")
            
#             elif(img.split("_")[1].split(".")[0]) and label.item()==1:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\multiple_disease")
                
#             elif(img.split("_")[1].split(".")[0]) and label.item()==2:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\rust")
                
#             elif(img.split("_")[1].split(".")[0]) and label.item()==3:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\scab")
                
#         elif search("Test",img):
#             shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Test")

# %%
# def create_train_data():
#     images=natsort.natsorted(os.listdir(DIR))
#     for img in tqdm(images):
#         label=get_label_img(img)
#         path=os.path.join(DIR,img)
        
#         if search("Train",img):
#             if (img.split("_")[1].split(".")[0]) and label.item()==0:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\healthy")
            
#             elif(img.split("_")[1].split(".")[0]) and label.item()==1:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\multiple_disease")
                
#             elif(img.split("_")[1].split(".")[0]) and label.item()==2:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\rust")
                
#             elif(img.split("_")[1].split(".")[0]) and label.item()==3:
#                 shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Train\scab")
                
#         elif search("Test",img):
#             shutil.copy(path,r"C:\Users\Omar Atef\apple\Dataset\Images\Test")

# %%
# shutil.os.mkdir(r'C:\Users\Omar Atef\apple\Dataset\Images\Train')
# shutil.os.mkdir(r'C:\Users\Omar Atef\apple\Dataset\Images\Train\healthy')
# shutil.os.mkdir(r'C:\Users\Omar Atef\apple\Dataset\Images\Train\multiple_disease')
# shutil.os.mkdir(r'C:\Users\Omar Atef\apple\Dataset\Images\Train\rust')
# shutil.os.mkdir(r'C:\Users\Omar Atef\apple\Dataset\Images\Train\scab')

# shutil.os.mkdir(r'C:\Users\Omar Atef\apple\Dataset\Images\Test')

# %%
# train_dir=create_train_data()

# %%
Train_DIR=r"C:\Users\Omar Atef\train"

# %%
sorted_train=natsort.natsorted(os.listdir(Train_DIR))

# %%
train_images=[]

# %%
train_label=[]

# %%
img_size=60

# %%
count=0

# %%
Train_DIR=r"C:\Users\Omar Atef\train"


for img in sorted_train:
        
    old_image=cv2.imread(os.path.join(Train_DIR,img),cv2.COLOR_BGR2RGB)
#   plt.imshow(old_image)
#   plt.show()
    new_image=cv2.resize(old_image,(img_size,img_size))
    train_images.append(new_image)
    train_label.append(train.iloc[count,-1])
    count=count+1

# %%
os.listdir(Train_DIR)
# Out:
# ['Train_0.jpg',
#  'Train_1.jpg',
#  'Train_10.jpg',
#  'Train_100.jpg',
#  'Train_1000.jpg',
#  'Train_1001.jpg',
#  'Train_1002.jpg',
#  'Train_1003.jpg',
#  'Train_1004.jpg',
#  'Train_1005.jpg',
#  'Train_1006.jpg',
#  'Train_1007.jpg',
#  'Train_1008.jpg',
#  'Train_1009.jpg',
#  'Train_101.jpg',
#  'Train_1010.jpg',
#  'Train_1011.jpg',
#  'Train_1012.jpg',
#  'Train_1013.jpg',
#  'Train_1014.jpg',
#  'Train_1015.jpg',
#  'Train_1016.jpg',
#  'Train_1017.jpg',
#  'Train_1018.jpg',
#  'Train_1019.jpg',
#  'Train_102.jpg',
#  'Train_1020.jpg',
#  'Train_1021.jpg',
#  'Train_1022.jpg',
#  'Train_1023.jpg',
#  'Train_1024.jpg',
#  'Train_1025.jpg',
#  'Train_1026.jpg',
#  'Train_1027.jpg',
#  'Train_1028.jpg',
#  'Train_1029.jpg',
#  'Train_103.jpg',
#  'Train_1030.jpg',
#  'Train_1031.jpg',
#  'Train_1032.jpg',
#  'Train_1033.jpg',
#  'Train_1034.jpg',
#  'Train_1035.jpg',
#  'Train_1036.jpg',
#  'Train_1037.jpg',
#  'Train_1038.jpg',
#  'Train_1039.jpg',
#  'Train_104.jpg',
# ...

# %%
len(train_images)
# Out:
# 1821

# %%
MU=np.mean(train_images)

# %%
Sigma=np.std(train_images)

# %%
imgee=[]

# %%
for img in train_images:
    img=(img-MU)/Sigma
    imgee.append(img)

# %%
plt.imshow(imgee[5])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
im = Image.fromarray(train_images[1])
plt.imshow(im)
plt.show()

# %%
train_images[0]
# Out:
# array([[[ 13,  54,  33],
#         [ 18,  60,  42],
#         [ 21,  67,  45],
#         ...,
#         [ 27,  63,  46],
#         [ 22,  50,  37],
#         [ 28,  62,  52]],
#
#        [[ 13,  54,  33],
#         [ 18,  59,  38],
#         [ 19,  61,  39],
#         ...,
#         [ 26,  50,  42],
#         [ 18,  50,  33],
#         [ 19,  54,  38]],
#
#        [[ 33,  85,  62],
#         [ 24,  66,  43],
#         [ 27,  71,  48],
#         ...,
#         [ 11,  42,  27],
#         [ 16,  62,  36],
#         [ 17,  67,  43]],
#
#        ...,
#
#        [[103, 179, 178],
#         [114, 173, 179],
#         [113, 158, 169],
#         ...,
#         [108, 213, 198],
#         [123, 209, 194],
#         [135, 206, 186]],
#
#        [[113, 177, 182],
#         [117, 163, 174],
#         [118, 150, 173],
#         ...,
#         [158, 210, 193],
#         [124, 199, 177],
#         [157, 215, 197]],
#
#        [[121, 171, 183],
#         [122, 153, 178],
#         [117, 147, 172],
# ...

# %%
imgee[0]
# Out:
# array([[[-1.69313168, -0.93395878, -1.32280344],
#         [-1.60054962, -0.82286031, -1.15615573],
#         [-1.54500039, -0.69324542, -1.10060649],
#         ...,
#         [-1.43390191, -0.76731107, -1.08209008],
#         [-1.52648397, -1.00802443, -1.24873779],
#         [-1.4153855 , -0.78582748, -0.97099161]],
#
#        [[-1.69313168, -0.93395878, -1.32280344],
#         [-1.60054962, -0.84137672, -1.23022138],
#         [-1.58203321, -0.8043439 , -1.21170497],
#         ...,
#         [-1.45241832, -1.00802443, -1.15615573],
#         [-1.60054962, -1.00802443, -1.32280344],
#         [-1.58203321, -0.93395878, -1.23022138]],
#
#        [[-1.32280344, -0.35995   , -0.78582748],
#         [-1.48945115, -0.71176184, -1.13763932],
#         [-1.43390191, -0.61917977, -1.04505726],
#         ...,
#         [-1.73016451, -1.15615573, -1.43390191],
#         [-1.63758245, -0.78582748, -1.2672542 ],
#         [-1.61906603, -0.69324542, -1.13763932]],
#
#        ...,
#
# ...

# %%
# for i in range(len(train_images)): 
#     im = Image.fromarray(train_images[i])
#     im.save(f"C:/Users/Omar Atef/resized60/train_{train_label[i]}_{i}.jpeg")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Activation,Flatten, Conv2D, MaxPooling2D,Dropout

# %%
datagen=ImageDataGenerator(  rotation_range=20,
                                horizontal_flip=True,
                                vertical_flip=True,
                                width_shift_range=0.1,
                                height_shift_range=0.1,
                                validation_split=0.2
                           
                          )

train_datagen=datagen.flow_from_directory(r"C:\Users\Omar Atef\apple\Dataset\resized60",
                                         target_size=(img_size,img_size),
                                         batch_size=32,
                                         class_mode='categorical',
                                         subset='training')

val_datagen=datagen.flow_from_directory(r"C:\Users\Omar Atef\apple\Dataset\resized60",
                                         target_size=(img_size,img_size),
                                         batch_size=32,
                                         class_mode='categorical',
                                         subset='validation')
# Out:
# Found 1458 images belonging to 4 classes.
# Found 363 images belonging to 4 classes.

# %%
model=Sequential()
# 
model.add(Conv2D(20,(5,5),input_shape=(60,60,3)))
model.add(Dropout(0.2))
model.add(Activation("relu"))
model.add(MaxPooling2D(2,2))
#
model.add(Conv2D(50,(5,5)))
model.add(Dropout(0.2))
model.add(Activation("relu"))
model.add(MaxPooling2D(2,2))
#
model.add(Flatten())
model.add(Dense(500))
model.add(Dropout(0.2))
model.add(Activation("relu"))

#
model.add(Dense(4))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Activation("softmax"))

# Compile the Model
model.compile(optimizer=("Adam"),loss='categorical_crossentropy',
    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 56, 56, 20)        1520
#
#  dropout (Dropout)           (None, 56, 56, 20)        0
#
#  activation (Activation)     (None, 56, 56, 20)        0
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 20)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 50)        25050
#
#  dropout_1 (Dropout)         (None, 24, 24, 50)        0
#
#  activation_1 (Activation)   (None, 24, 24, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 50)       0
#  2D)
#
#  flatten (Flatten)           (None, 7200)              0
#
#  dense (Dense)               (None, 500)               3600500
#
#  dropout_2 (Dropout)         (None, 500)               0
#
#  activation_2 (Activation)   (None, 500)               0
#
#  dense_1 (Dense)             (None, 4)                 2004
#
# ...

# %%
# checkpoint=ModelCheckpoint(r'D:\Python37\Projects\Foliar diseases in apple trees\models\apple2.h5',
#                           monitor='val_loss',
#                           mode='min',
#                           save_best_only=True,
#                           verbose=1)
# earlystop=EarlyStopping(monitor='val_loss',
#                        min_delta=0,
#                        patience=10,
#                        verbose=1,
#                        restore_best_weights=True)

# callbacks=[checkpoint,earlystop]

# %%
model_history=model.fit(train_datagen,validation_data=val_datagen,
                                 epochs=30,
                                 batch_size=12,)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 11s 222ms/step - loss: 39.1933 - accuracy: 0.3189 - val_loss: 1.3307 - val_accuracy: 0.3581
# Epoch 2/30
# 46/46 [==============================] - 4s 85ms/step - loss: 1.3060 - accuracy: 0.3244 - val_loss: 1.2908 - val_accuracy: 0.3388
# Epoch 3/30
# 46/46 [==============================] - 4s 87ms/step - loss: 1.2863 - accuracy: 0.3450 - val_loss: 1.2711 - val_accuracy: 0.3719
# Epoch 4/30
# 46/46 [==============================] - 4s 94ms/step - loss: 1.2827 - accuracy: 0.3450 - val_loss: 1.2699 - val_accuracy: 0.3361
# Epoch 5/30
# 46/46 [==============================] - 4s 96ms/step - loss: 1.2728 - accuracy: 0.3381 - val_loss: 1.2593 - val_accuracy: 0.3251
# Epoch 6/30
# 46/46 [==============================] - 4s 94ms/step - loss: 1.2588 - accuracy: 0.3560 - val_loss: 1.2459 - val_accuracy: 0.3581
# Epoch 7/30
# ...

# %%
acc_train=model_history.history['accuracy']
acc_val=model_history.history['val_accuracy']
epochs=range(1,31)
plt.plot(epochs,acc_train,'g',label='Training Accuracy')
plt.plot(epochs,acc_val,'b',label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
loss_train=model_history.history['loss']
loss_val=model_history.history['val_loss']
epochs=range(1,31)
plt.plot(epochs,loss_train,'g',label='Training Loss')
plt.plot(epochs,loss_val,'b',label='Validation Loss')
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
test_image=r"C:\Users\Omar Atef\apple\Dataset\resized60\rust\train_2_3.jpeg"
image_result=Image.open(test_image)

from tensorflow.keras.preprocessing import image
test_image=image.load_img(test_image,target_size=(60,60))
test_image=image.img_to_array(test_image)
test_image=test_image/255
test_image=np.expand_dims(test_image,axis=0)
result=model.predict(test_image)
print(np.argmax(result))
Categories=['healthy','multiple_disease','rust','scab']
image_result=plt.imshow(image_result)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 3
